# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
#halaman 1
url = 'https://www.sephora.com/shop/makeup-cosmetics'
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36','Accept-Language':'en-US,en;q=0.5'})
response = requests.get(url, headers=HEADERS)
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# ...

# %%
links = soup.find_all("a", attrs={'class':'css-klx76'})
links
# Out:
# [<a class="css-klx76" data-comp="ProductTile " href="https://www.sephora.com/product/ilia-super-serum-skin-tint-spf-40-P455418?skuId=2333607&amp;icid2=products grid:p455418:product"><div class="css-1jxmy2m eanm77i0" data-comp="StyledComponent BaseComponent "><div class="css-mnsjf0 eanm77i0" data-comp="ProductImage StyledComponent BaseComponent "><picture class="css-yq9732"><source media="(min-width: 768px)" srcset="https://www.sephora.com/productimages/sku/s2333607-main-zoom.jpg?pb=allure-best-2020&amp;imwidth=250 1x, https://www.sephora.com/productimages/sku/s2333607-main-zoom.jpg?pb=allure-best-2020&amp;imwidth=500 2x"/><img alt="ILIA - Super Serum Skin Tint SPF 40 Foundation" class="css-1rovmyu eanm77i0" data-comp="StyledComponent BaseComponent " src="https://www.sephora.com/productimages/sku/s2333607-main-zoom.jpg?pb=allure-best-2020&amp;imwidth=175" srcset="https://www.sephora.com/productimages/sku/s2333607-main-zoom.jpg?pb=allure-best-2020&amp;imwidth=175 1x, https://www.sephor
# ...

# %%
links_list = []

# %%
for link in links:
        links_list.append(link.get('href'))
links_list
# Out:
# ['https://www.sephora.com/product/ilia-super-serum-skin-tint-spf-40-P455418?skuId=2333607&icid2=products grid:p455418:product',
#  'https://www.sephora.com/product/rare-beauty-by-selena-gomez-soft-pinch-liquid-blush-P97989778?skuId=2640241&icid2=products grid:p97989778:product',
#  'https://www.sephora.com/product/rare-beauty-by-selena-gomez-soft-pinch-tinted-lip-oil-P505568?skuId=2640159&icid2=products grid:p505568:product',
#  'https://www.sephora.com/product/rare-beauty-by-selena-gomez-positive-light-liquid-luminizer-highlight-P38855877?skuId=2362168&icid2=products grid:p38855877:product',
#  'https://www.sephora.com/product/ilia-super-serum-skin-tint-spf-40-P455418?skuId=2333607&icid2=products grid:p455418:product',
#  'https://www.sephora.com/product/rare-beauty-by-selena-gomez-soft-pinch-liquid-blush-P97989778?skuId=2640241&icid2=products grid:p97989778:product',
# ...

# %%
# ekstrak link produk 1
p1 = links_list[0]
p1
# Out:
# 'https://www.sephora.com/product/ilia-super-serum-skin-tint-spf-40-P455418?skuId=2333607&icid2=products grid:p455418:product'

# %%
# ekstrak info produk 1
new_webpage1 = requests.get(p1, headers=HEADERS)
new_soup1 = BeautifulSoup(new_webpage1.content, "html.parser")
brand1 = new_soup1.find("a", attrs={"data-at":'brand_name'}).text.strip()
product1 = new_soup1.find("span", attrs={"data-at":'product_name'}).text.strip()
price1 = new_soup1.find("b", attrs={"class":'css-0'}).text.strip()
likes1 = new_soup1.find("span", attrs={"class":'css-jk94q9'}).text.strip()
size1 = new_soup1.find("span", attrs={"data-at":'sku_size_label'}).text.strip()
deskripsi1 = new_soup1.find("p", attrs={"class":'css-1a157mi eanm77i0'}).text.strip()

# %%
# ekstrak link dan info produk 2
p2 = links_list[1]
p2
new_webpage2 = requests.get(p2, headers=HEADERS)
new_soup2 = BeautifulSoup(new_webpage2.content, "html.parser")
brand2 = new_soup2.find("a", attrs={"data-at":'brand_name'}).text.strip()
product2 = new_soup2.find("span", attrs={"data-at":'product_name'}).text.strip()
price2 = new_soup2.find("b", attrs={"class":'css-0'}).text.strip()
likes2 = new_soup2.find("span", attrs={"class":'css-jk94q9'}).text.strip()
size2 = new_soup2.find("span", attrs={"data-at":'sku_size_label'}).text.strip()
deskripsi2 = new_soup2.find("p", attrs={"class":'css-1a157mi eanm77i0'}).text.strip()

# %%
# ekstrak link dan info produk 3
p3 = links_list[2]
p3
new_webpage3 = requests.get(p3, headers=HEADERS)
new_soup3 = BeautifulSoup(new_webpage3.content, "html.parser")
brand3 = new_soup3.find("a", attrs={"data-at":'brand_name'}).text.strip()
product3 = new_soup3.find("span", attrs={"data-at":'product_name'}).text.strip()
price3 = new_soup3.find("b", attrs={"class":'css-0'}).text.strip()
likes3 = new_soup3.find("span", attrs={"class":'css-jk94q9'}).text.strip()
size3 = new_soup3.find("span", attrs={"data-at":'sku_size_label'}).text.strip()
deskripsi3 = new_soup3.find("p", attrs={"class":'css-1a157mi eanm77i0'}).text.strip()

# %%
# ekstrak link dan info produk 4
p4 = links_list[3]
p4
new_webpage4 = requests.get(p4, headers=HEADERS)
new_soup4 = BeautifulSoup(new_webpage4.content, "html.parser")
brand4 = new_soup4.find("a", attrs={"data-at":'brand_name'}).text.strip()
product4 = new_soup4.find("span", attrs={"data-at":'product_name'}).text.strip()
price4 = new_soup4.find("b", attrs={"class":'css-0'}).text.strip()
likes4 = new_soup4.find("span", attrs={"class":'css-jk94q9'}).text.strip()
size4 = new_soup4.find("span", attrs={"data-at":'sku_size_label'}).text.strip()
deskripsi4 = new_soup4.find("p", attrs={"class":'css-1a157mi eanm77i0'}).text.strip()

# %%
sephora = pd.DataFrame({'Nama Brand':brand1, 'Nama Produk':product1, 'Harga':price1,'Jumlah Likes':likes1,
         'Size': size1,'Deskripsi Produk':deskripsi1}, index=[0])
sephora = sephora.append({'Nama Brand':brand2, 'Nama Produk':product2, 'Harga':price2,'Jumlah Likes':likes2,
         'Size': size2,'Deskripsi Produk':deskripsi2}, ignore_index=True)
sephora = sephora.append({'Nama Brand':brand3, 'Nama Produk':product3, 'Harga':price3,'Jumlah Likes':likes3,
         'Size': size3,'Deskripsi Produk':deskripsi3}, ignore_index=True)
sephora = sephora.append({'Nama Brand':brand4, 'Nama Produk':product4, 'Harga':price4,'Jumlah Likes':likes4,
         'Size': size4,'Deskripsi Produk':deskripsi4}, ignore_index=True)
sephora
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3380\3474950194.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sephora = sephora.append({'Nama Brand':brand2, 'Nama Produk':product2, 'Harga':price2,'Jumlah Likes':likes2,
# C:\Users\user\AppData\Local\Temp\ipykernel_3380\3474950194.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sephora = sephora.append({'Nama Brand':brand3, 'Nama Produk':product3, 'Harga':price3,'Jumlah Likes':likes3,
# C:\Users\user\AppData\Local\Temp\ipykernel_3380\3474950194.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sephora = sephora.append({'Nama Brand':brand4, 'Nama Produk':product4, 'Harga':price4,'Jumlah Likes':likes4,
# ...

# %%
sephora.to_csv('sephorascrapingdata.csv')
